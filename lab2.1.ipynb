# %% [markdown]
# ## Exercise: Analyzing and Visualizing Data with Matplotlib, Pandas, and NumPy
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per $10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's
#
# ### Part 1: Data Preparation
#
# In this part of the exercise, you will use Pandas and NumPy to load and preprocess data. For this exercise, we will use a dataset of housing prices in Boston.
#
# 1.  Download the Boston Housing dataset from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data) and save it to your local computer.
# 2.  Load the dataset into a Pandas DataFrame and examine its contents. The dataset should have 506 rows and 14 columns.
# 3.  Use NumPy to calculate some basic statistics about the dataset, such as the mean, median, standard deviation, minimum, and maximum values of each column.
# 4.  Clean the dataset by removing any missing or invalid values. You can use Pandas' `dropna()` method for this.

# %%
# %pip install pandas yfinance matplotlib seaborn
# Out:
# Collecting pandas
#   Using cached pandas-2.2.1-cp39-cp39-win_amd64.whl (11.6 MB)
# Collecting yfinance
#   Using cached yfinance-0.2.37-py2.py3-none-any.whl (72 kB)
# Requirement already satisfied: matplotlib in c:\users\a507\bonic_paula\1\lib\site-packages (3.8.3)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\a507\bonic_paula\1\lib\site-packages (from pandas) (1.26.4)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a507\bonic_paula\1\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting appdirs>=1.4.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting requests>=2.31
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting beautifulsoup4>=4.11.1
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting lxml>=4.9.1
#   Using cached lxml-5.1.0-cp39-cp39-win_amd64.whl (3.9 MB)
# Collecting html5lib>=1.1
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting peewee>=3.16.2
#   Using cached peewee-3.17.1-py3-none-any.whl
# Collecting frozendict>=2.3.4
#   Using cached frozendict-2.4.0-cp39-cp39-win_amd64.whl (36 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: pillow>=8 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\a507\bonic_paula\1\lib\site-packages (from matplotlib) (3.1.2)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: six>=1.9 in c:\users\a507\bonic_paula\1\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\a507\bonic_paula\1\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl (100 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Installing collected packages: webencodings, pytz, peewee, multitasking, appdirs, urllib3, tzdata, soupsieve, lxml, idna, html5lib, frozendict, charset-normalizer, certifi, requests, pandas, beautifulsoup4, yfinance, seaborn
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.12.3 certifi-2024.2.2 charset-normalizer-3.3.2 frozendict-2.4.0 html5lib-1.1 idna-3.6 lxml-5.1.0 multitasking-0.0.11 pandas-2.2.1 peewee-3.17.1 pytz-2024.1 requests-2.31.0 seaborn-0.13.2 soupsieve-2.5 tzdata-2024.1 urllib3-2.2.1 webencodings-0.5.1 yfinance-0.2.37
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\A507\bonic_paula\1\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PIRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv('housing.data', delim_whitespace=True, header=None, names=names)

print(df.head())
print(df.shape)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PIRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# (506, 14)
# C:\Users\A507\AppData\Local\Temp\ipykernel_17828\1130635704.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('housing.data', delim_whitespace=True, header=None, names=names)

# %% [markdown]
# ### Part 2: Data Visualization
#
# In this part of the exercise, you will use Matplotlib to create some visualizations of the housing data.
#
# 1.  Create a scatter plot of the housing prices (`MEDV`) versus the number of rooms (`RM`). Label the axes and add a title to the plot.
# 2.  Create a histogram of the housing prices (`MEDV`). Label the axes and add a title to the plot.
# 3.  Create a box plot of the housing prices (`MEDV`) grouped by the proximity to employment centers (`DIS`). Label the axes and add a title to the plot.

# %%
import numpy as np

mean = np.mean(df, axis = 0)
median = np.median(df, axis=0)
std = np.std(df, axis = 0)
minimum = np.min(df, axis=0)
maximum = np.min(df, axis=0)

print("Mean:\n", mean)
# Out:
# Mean:
#  CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PIRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# MEDV        22.532806
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.boxplot([df[df['DIS'] < 2]['MEDV'],
            df[(df['DIS'] >= 2) & (df['DIS'] < 4)]['MEDV'],
            df[(df['DIS'] >= 4) & (df['DIS'] < 6)]['MEDV'],
            df[df['DIS'] >= 6]['MEDV']],
            labels=['<2', '2-4', '4-6', '>=6'])

plt.title('Box Plot of Housing Prices Grouped by Proximity to Employment Centers')
plt.xlabel('Proximity to Employment Centers (DIS)')
plt.ylabel('Housing Prices (MEDV)')
plt.grid(True)
plt.show()

# %%
plt.scatter(df['RM'], df['MEDV'])
plt.title('Housing Prices vs. Number of Rooms')
plt.xlabel('Number of Rooms')
plt.ylabel('Housing prices')
plt.show()

# %%
plt.hist(df['MEDV'], bins=30)
plt.title('Housing Prices Histogram')
plt.xlabel('Housing Prices')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Part 3: Data Analysis
#
# In this part of the exercise, you will use Pandas and NumPy to perform some basic data analysis on the housing data.
#
# 1.  Calculate the correlation coefficient between the housing prices (`MEDV`) and the number of rooms (`RM`) using NumPy's `corrcoef()` method.
# 2.  Calculate the mean housing price (`MEDV`) for each neighborhood (`CHAS`). You can use Pandas' `groupby()` method for this.
# 3.  Calculate the percentage of houses that have more than 7 rooms (`RM`). You can use Pandas' `value_counts()` method for this.

# %%
df=df.dropna()
print(df.isnull().values.any())
print(df.head())
print(df.shape)

# 1. Calculate the correlation coefficient between housing prices (MEDV) and number of rooms (RM)
correlation_coefficient = np.corrcoef(df['RM'], df['MEDV'])[0, 1]
print("Correlation coefficient between MEDV and RM:", correlation_coefficient)

# 2. Calculate the mean housing price (MEDV) for each neighborhood (CHAS)
mean_prices_by_neighborhood = df.groupby('CHAS')['MEDV'].mean()
print("\nMean housing prices (MEDV) for each neighborhood (CHAS):")
print(mean_prices_by_neighborhood)

# 3. Calculate the percentage of houses that have more than 7 rooms (RM)
percentage_more_than_7_rooms = (df['RM'] > 7).mean() * 100
print("\nPercentage of houses with more than 7 rooms (RM): {:.2f}%".format(percentage_more_than_7_rooms))
# Out:
# False
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PIRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# (506, 14)
# Correlation coefficient between MEDV and RM: 0.6953599470715395
#
# Mean housing prices (MEDV) for each neighborhood (CHAS):
# CHAS
# 0    22.093843
# 1    28.440000
# Name: MEDV, dtype: float64
#
# Percentage of houses with more than 7 rooms (RM): 12.65%

# %% [markdown]
# ### Part 4: Putting it all together
#
# In this final part of the exercise, you will use all three libraries to create a complete data analysis and visualization pipeline.
#
# 1.  Load the dataset and preprocess it as before.
# 2.  Create the scatter plot and histogram as before.
# 3.  Calculate the correlation coefficient between the housing prices and the number of rooms as before.
# 4.  Group the data by the proximity to employment centers and calculate the mean housing prices as before.
# 5.  Create a bar chart of the mean housing prices by proximity to employment centers. Label the axes and add a title to the plot.
