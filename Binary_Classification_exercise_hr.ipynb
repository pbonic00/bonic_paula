# %% [markdown]
# # Uvod #
#
# U ovoj vježbi izgradit ćete model za predviđanje otkazivanja hotela s binarnim klasifikatorom.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# Prvo učitajte skup podataka *Hotel cancellations*.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./input/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.preprocessing import StandardScaler, OneHotEncoder
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\__init__.py:166
#     147 from pandas.core.computation.api import eval
#     149 from pandas.core.reshape.api import (
#     150     concat,
#     151     lreshape,
#    (...)
#     163     qcut,
#     164 )
# --> 166 from pandas import api, arrays, errors, io, plotting, tseries
#     167 from pandas import testing
#     168 from pandas.util._print_versions import show_versions
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %% [markdown]
# # 1) Definirajte model #
#
# Model koji ćemo ovaj put koristiti imat će i batch normalization i dropout layer. Radi lakšeg čitanja razbili smo dijagram u blokove, ali možete ga definirati sloj po sloj kao i obično.
#
# Definirajte model s arhitekturom danom ovim dijagramom:
#
# <figure style="padding: 1em;">
# <img src="figs/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Dijagram binarnog klasifikatora.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation="sigmoid"),
])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 from tensorflow import keras
# ----> 2 from tensorflow.keras import layers
#       4 model = keras.Sequential([
#       5     layers.BatchNormalization(input_shape=input_shape),
#       6     layers.Dense(512, activation='relu'),
#    (...)
#      15     layers.Dense(1, activation="sigmoid"),
#      16 ])
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\_tf_keras\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\_tf_keras\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\activations\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.src.activations import deserialize
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\activations\__init__.py:22
#      20 from keras.src.activations.activations import tanh
#      21 from keras.src.api_export import keras_export
# ---> 22 from keras.src.saving import object_registration
#      23 from keras.src.saving import serialization_lib
#      25 ALL_OBJECTS = {
#      26     relu,
#      27     leaky_relu,
#    (...)
#      43     log_softmax,
#      44 }
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\saving\__init__.py:7
#       5 from keras.src.saving.object_registration import get_registered_object
#       6 from keras.src.saving.object_registration import register_keras_serializable
# ----> 7 from keras.src.saving.saving_api import load_model
#       8 from keras.src.saving.serialization_lib import deserialize_keras_object
#       9 from keras.src.saving.serialization_lib import serialize_keras_object
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\saving\saving_api.py:7
#       4 from absl import logging
#       6 from keras.src.api_export import keras_export
# ----> 7 from keras.src.legacy.saving import legacy_h5_format
#       8 from keras.src.saving import saving_lib
#       9 from keras.src.utils import file_utils
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:13
#      11 from keras.src.legacy.saving import json_utils
#      12 from keras.src.legacy.saving import saving_options
# ---> 13 from keras.src.legacy.saving import saving_utils
#      14 from keras.src.saving import object_registration
#      15 from keras.src.utils import io_utils
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\legacy\saving\saving_utils.py:10
#       8 from keras.src import losses
#       9 from keras.src import metrics as metrics_module
# ---> 10 from keras.src import models
#      11 from keras.src import optimizers
#      12 from keras.src.legacy.saving import serialization
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\models\__init__.py:1
# ----> 1 from keras.src.models.functional import Functional
#       2 from keras.src.models.model import Model
#       3 from keras.src.models.sequential import Sequential
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\models\functional.py:14
#      12 from keras.src.legacy.saving import saving_utils
#      13 from keras.src.legacy.saving import serialization as legacy_serialization
# ---> 14 from keras.src.models.model import Model
#      15 from keras.src.ops.function import Function
#      16 from keras.src.ops.function import _build_map
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\models\model.py:13
#      11 from keras.src.saving import saving_api
#      12 from keras.src.saving import saving_lib
# ---> 13 from keras.src.trainers import trainer as base_trainer
#      14 from keras.src.utils import io_utils
#      15 from keras.src.utils import summary_utils
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\trainers\trainer.py:12
#      10 from keras.src.trainers.compile_utils import CompileLoss
#      11 from keras.src.trainers.compile_utils import CompileMetrics
# ---> 12 from keras.src.trainers.data_adapters import data_adapter_utils
#      13 from keras.src.utils import traceback_utils
#      14 from keras.src.utils import tracking
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\trainers\data_adapters\__init__.py:4
#       1 import types
#       3 from keras.src.distribution import distribution_lib
# ----> 4 from keras.src.trainers.data_adapters import array_data_adapter
#       5 from keras.src.trainers.data_adapters import py_dataset_adapter
#       6 from keras.src.trainers.data_adapters.array_data_adapter import ArrayDataAdapter
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:6
#       2 import math
#       4 import numpy as np
# ----> 6 from keras.src.trainers.data_adapters import array_slicing
#       7 from keras.src.trainers.data_adapters import data_adapter_utils
#       8 from keras.src.trainers.data_adapters.data_adapter import DataAdapter
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py:11
#       8 from keras.src.utils import tree
#      10 try:
# ---> 11     import pandas
#      12 except ImportError:
#      13     pandas = None
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\__init__.py:166
#     147 from pandas.core.computation.api import eval
#     149 from pandas.core.reshape.api import (
#     150     concat,
#     151     lreshape,
#    (...)
#     163     qcut,
#     164 )
# --> 166 from pandas import api, arrays, errors, io, plotting, tseries
#     167 from pandas import testing
#     168 from pandas.util._print_versions import show_versions
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\A507\bonic_paula\Lab3_online\labs\lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %% [markdown]
# # 2) Dodajte optimizator, loss i metriku #
#
# Sada sastavite model s Adamovim optimizatorom i binarnim verzijama cross-entropy loss-a i metrike accuracy-a.

# %%
# YOUR CODE HERE
____

# %% [markdown]
# Na kraju, pokrenite ovu ćeliju da uvježbate model i pogledate krivulje učenja. Može trajati oko 60 do 70 epoha, što može potrajati minutu ili dvije.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")

# %% [markdown]
# # 3) Train and verify #
#
#
# Što mislite o krivuljama učenja? Izgleda li kao model underfit ili overfit? Je li cross-entropy loss bio dobra zamjena za accuracy?
